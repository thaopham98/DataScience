# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %% [markdown]
# ## Exploration Data Analytics (EDA)

# %%
df = pd.read_excel(r"C:..\data\police_ incident_reports.xlsx")
df.head()
# Out:
#      Incident Datetime Incident Date Incident Time  Incident Year  \
# 0  2021-01-20 18:00:00    2021-01-20      18:00:00           2021
# 1  2021-11-24 12:30:00    2021-11-24      12:30:00           2021
# 2  2021-09-06 10:00:00    2021-09-05      10:00:00           2021
# 3  2022-03-17 13:00:00    2022-03-16      13:00:00           2022
# 4  2022-03-27 15:00:00    2022-03-26      15:00:00           2022
#
#   Incident Day of Week      Report Datetime  Incident ID  Incident Number  \
# 0            Wednesday   2021-01-21 1:15:00       997983        210006082
# 1            Wednesday  2021-11-24 13:54:00      1095709        216181238
# 2               Sunday  2021-09-05 12:38:00      1068863        216125543
# 3            Wednesday  2022-03-16 13:00:00      1131418        220094613
# 4             Saturday  2022-03-27 10:01:00      1138330        226056041
#
#   Report Type Code Report Type Description  Filed Online  Incident Code  \
# 0               IS      Initial Supplement          True           4011
# 1               II        Coplogic Initial          True           6244
# 2               II        Coplogic Initial          True           6244
# 3               VS      Vehicle Supplement         False           7045
# 4               II        Coplogic Initial          True          28150
#
#     Incident Category    Incident Subcategory  \
# 0             Assault      Aggravated Assault
# 1       Larceny Theft  Larceny - From Vehicle
# 2       Larceny Theft  Larceny - From Vehicle
# 3   Recovered Vehicle       Recovered Vehicle
# 4  Malicious Mischief               Vandalism
#
#                         Incident Description  Incident Cost Estimate  \
# 0                Assault, Aggravated, W/ Gun                       0
# 1          Theft, From Locked Vehicle, >$950                     950
# 2          Theft, From Locked Vehicle, >$950                     950
# 3                  Vehicle, Recovered, Truck                       0
# 4  Malicious Mischief, Vandalism to Property                       0
#
#        Resolution Police District
# 0  Open or Active       Out of SF
# 1  Open or Active            Park
# 2  Open or Active       Ingleside
# 3  Open or Active       Out of SF
# 4  Open or Active        Southern

# %%
df.shape
# Out:
# (10000, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Incident Datetime        10000 non-null  object
#  1   Incident Date            10000 non-null  object
#  2   Incident Time            10000 non-null  object
#  3   Incident Year            10000 non-null  int64
#  4   Incident Day of Week     10000 non-null  object
#  5   Report Datetime          10000 non-null  object
#  6   Incident ID              10000 non-null  int64
#  7   Incident Number          10000 non-null  int64
#  8   Report Type Code         10000 non-null  object
#  9   Report Type Description  10000 non-null  object
#  10  Filed Online             10000 non-null  bool
#  11  Incident Code            10000 non-null  int64
#  12  Incident Category        9988 non-null   object
#  13  Incident Subcategory     9988 non-null   object
#  14  Incident Description     10000 non-null  object
#  15  Incident Cost Estimate   10000 non-null  int64
#  16  Resolution               10000 non-null  object
#  17  Police District          10000 non-null  object
# dtypes: bool(1), int64(5), object(12)
# memory usage: 1.3+ MB

# %%
print(f'Total Cost Estimate: ${df["Incident Cost Estimate"].sum()}')
df["Incident Cost Estimate"].value_counts()
# Out:
# Total Cost Estimate: $1868550
# Incident Cost Estimate
# 0      7369
# 950    1876
# 50      431
# 200     324
# Name: count, dtype: int64

# %% [markdown]
# ## Missing Data

# %%
def check_missing_data(df):
    percent_missing = df.isnull().sum()
    print(f'Number of NaN values for each column:\n{percent_missing}')

    total_cells = np.prod(df.shape)
    print(f'Total Cells: {total_cells}')

    total_missing = percent_missing.sum()
    print(f'Total Missing: {total_missing}')

    print(f'Percent Missing: {(total_missing/total_cells) * 100}%')

check_missing_data(df)
# Out:
# Number of NaN values for each column:
# Incident Datetime           0
# Incident Date               0
# Incident Time               0
# Incident Year               0
# Incident Day of Week        0
# Report Datetime             0
# Incident ID                 0
# Incident Number             0
# Report Type Code            0
# Report Type Description     0
# Filed Online                0
# Incident Code               0
# Incident Category          12
# Incident Subcategory       12
# Incident Description        0
# Incident Cost Estimate      0
# Resolution                  0
# Police District             0
# dtype: int64
# Total Cells: 180000
# Total Missing: 24
# Percent Missing: 0.013333333333333334%

# %%
df[df['Incident Category'].isnull() & df['Incident Subcategory'].isnull()] # display the missing data rows
# Out:
#         Incident Datetime Incident Date Incident Time  Incident Year  \
# 42    2023-03-26 21:52:00    2023-03-25      21:52:00           2023
# 1208  2023-09-10 19:10:00    2023-09-09      19:10:00           2023
# 1859  2022-07-09 16:01:00    2022-07-08      16:01:00           2022
# 1898  2021-07-12 17:29:00    2021-07-11      17:29:00           2021
# 1997   2021-06-21 0:01:00    2021-06-20       0:01:00           2021
# 3947  2023-01-15 17:36:00    2023-01-14      17:36:00           2023
# 5481   2021-04-19 8:41:00    2021-04-18       8:41:00           2021
# 7220  2020-04-12 16:06:00    2020-04-11      16:06:00           2020
# 7897  2020-04-04 13:44:00    2020-04-03      13:44:00           2020
# 8181  2020-02-17 21:10:00    2020-02-16      21:10:00           2020
# 8534  2020-04-30 10:04:00    2020-04-29      10:04:00           2020
# 9112  2020-05-19 17:25:00    2020-05-18      17:25:00           2020
#
#      Incident Day of Week      Report Datetime  Incident ID  Incident Number  \
# 42               Saturday  2023-03-25 21:55:00      1258009        230209830
# 1208             Saturday  2023-09-09 19:10:00      1316944        230647177
# 1859               Friday  2022-07-08 16:17:00      1168777        220450479
# 1898               Sunday  2021-07-11 17:29:00      1049459        210437813
# 1997               Sunday   2021-06-20 0:01:00      1041875        210384333
# 3947             Saturday  2023-01-14 17:36:00      1234657        230030710
# 5481               Sunday   2021-04-18 8:41:00      1022671        210237180
# 7220             Saturday  2020-04-11 16:06:00       918893        200232645
# 7897               Friday  2020-04-03 13:44:00       917229        200221422
# 8181               Sunday  2020-02-16 21:12:00       903544        200119128
# 8534            Wednesday  2020-04-29 10:04:00       923230        200266666
# 9112               Monday  2020-05-18 17:26:00       928034        200303008
#
#      Report Type Code Report Type Description  Filed Online  Incident Code  \
# 42                 II                 Initial         False          15164
# 1208               II                 Initial         False          65021
# 1859               II                 Initial          True          15164
# 1898               II                 Initial          True          65021
# 1997               II                 Initial         False          65021
# 3947               IS      Initial Supplement          True          15164
# 5481               IS      Initial Supplement         False          65021
# 7220               IS      Initial Supplement         False          27400
# 7897               II                 Initial          True          27400
# 8181               II                 Initial          True          65021
# 8534               II                 Initial         False          27400
# 9112               II                 Initial         False          27400
#
#      Incident Category Incident Subcategory  \
# 42                 NaN                  NaN
# 1208               NaN                  NaN
# 1859               NaN                  NaN
# 1898               NaN                  NaN
# 1997               NaN                  NaN
# 3947               NaN                  NaN
# 5481               NaN                  NaN
# 7220               NaN                  NaN
# 7897               NaN                  NaN
# 8181               NaN                  NaN
# 8534               NaN                  NaN
# 9112               NaN                  NaN
#
#                              Incident Description  Incident Cost Estimate  \
# 42                 Gun Violence Restraining Order                       0
# 1208         Driving, Stunt Vehicle/Street Racing                       0
# 1859               Gun Violence Restraining Order                       0
# 1898         Driving, Stunt Vehicle/Street Racing                       0
# 1997         Driving, Stunt Vehicle/Street Racing                       0
# 3947               Gun Violence Restraining Order                       0
# 5481         Driving, Stunt Vehicle/Street Racing                       0
# 7220  Public Health Order Violation, Notification                       0
# 7897  Public Health Order Violation, Notification                       0
# 8181         Driving, Stunt Vehicle/Street Racing                       0
# 8534  Public Health Order Violation, Notification                       0
# 9112  Public Health Order Violation, Notification                       0
#
#                 Resolution Police District
# 42          Open or Active         Mission
# 1208  Cite or Arrest Adult         Bayview
# 1859        Open or Active            Park
# 1898             Unfounded         Mission
# 1997        Open or Active         Mission
# 3947        Open or Active        Richmond
# 5481  Cite or Arrest Adult         Bayview
# 7220        Open or Active        Northern
# 7897        Open or Active         Mission
# 8181        Open or Active         Bayview
# 8534        Open or Active            Park
# 9112  Cite or Arrest Adult         Taraval

# %%
# List of columns to exclude
exclude_columns = [
    'Incident Datetime', 'Incident Date', 'Incident Time', 'Incident Day of Week',
    'Report Datetime', 'Report Type Description', 'Report Type Code', 'Incident Description'
]

# Filter categorical columns (excluding the specified columns)
categorical_columns = df.select_dtypes(include=['object', 'category']).columns
categorical_columns = [col for col in categorical_columns if col not in exclude_columns]

# Print unique values for each categorical column
for col in categorical_columns:
    print(f"Unique values in '{col}':")
    print(df[col].unique())
    print("-" * 50)  # Separator for readability
# Out:
# Unique values in 'Incident Category':
# ['Assault' 'Larceny Theft' 'Recovered Vehicle' 'Malicious Mischief'
#  'Burglary' 'Disorderly Conduct' 'Lost Property' 'Motor Vehicle Theft'
#  'Non-Criminal' 'Offences Against The Family And Children'
#  'Other Offenses' 'Other Miscellaneous' 'Weapons Offense' 'Other' 'Fraud'
#  nan 'Robbery' 'Warrant' 'Weapons Carrying Etc' 'Drug Offense'
#  'Miscellaneous Investigation' 'Suspicious Occ' 'Courtesy Report'
#  'Forgery And Counterfeiting' 'Traffic Violation Arrest'
#  'Traffic Collision' 'Missing Person' 'Vehicle Impounded'
#  'Stolen Property' 'Embezzlement' 'Homicide' 'Arson' 'Liquor Laws'
#  'Case Closure' 'Rape' 'Drug Violation' 'Suicide' 'Fire Report'
#  'Sex Offense' 'Vandalism' 'Prostitution' 'Vehicle Misplaced'
#  'Human Trafficking (A), Commercial Sex Acts' 'Civil Sidewalks'
#  'Motor Vehicle Theft?']
# --------------------------------------------------
# Unique values in 'Incident Subcategory':
# ['Aggravated Assault' 'Larceny - From Vehicle' 'Recovered Vehicle'
#  'Vandalism' 'Larceny Theft - Other' 'Theft From Vehicle'
#  'Burglary - Other' 'Intimidation' 'Lost Property' 'Motor Vehicle Theft'
#  'Other' 'Simple Assault' 'Other Offenses' 'Extortion-Blackmail'
#  'Weapons Offense' 'Fraud' nan 'Non-Criminal' 'Burglary - Residential'
#  'Robbery - Other' 'Burglary - Hot Prowl' 'Larceny Theft - Shoplifting'
#  'Burglary - Commercial' 'Larceny Theft - From Building' 'Drug Violation'
#  'Trespass' 'Miscellaneous Investigation' 'Suspicious Occ'
#  'Larceny - Auto Parts' 'Courtesy Report' 'Forgery And Counterfeiting'
#  'Robbery - Street' 'Robbery - Commercial' 'Larceny Theft - Pickpocket'
#  'Disorderly Conduct' 'Robbery - Carjacking' 'Warrant'
#  'Traffic Violation Arrest' 'Traffic Collision - Hit & Run'
#  'Missing Person' 'Missing Adult' 'Vehicle Impounded'
#  'Motor Vehicle Theft (Attempted)' 'Larceny Theft - Bicycle'
#  'Stolen Property' 'Drunkenness' 'Embezzlement' 'Manslaughter' 'Arson'
#  'Liquor Law Violation' 'Case Closure' 'Rape - Attempted'
#  'Traffic Collision' 'Suicide' 'Fire Report' 'Sex Offense' 'Stalking'
#  'Larceny Theft - Purse Snatch' 'Kidnapping' 'Bad Checks' 'Loitering'
#  'Prostitution' 'Vehicle Misplaced'
#  'Human Trafficking, Commercial Sex Acts' 'Rape']
# --------------------------------------------------
# Unique values in 'Resolution':
# ['Open or Active' 'Cite or Arrest Adult' 'Exceptional Adult' 'Unfounded']
# --------------------------------------------------
# Unique values in 'Police District':
# ['Out of SF' 'Park' 'Ingleside' 'Southern' 'Richmond' 'Bayview' 'Taraval'
#  'Central' 'Mission' 'Tenderloin' 'Northern']
# --------------------------------------------------

# %%
# Update the values in the 'Incident Category' column
df['Incident Category'] = df['Incident Category'].str.replace('Motor Vehicle Theft?', 'Motor Vehicle Theft', regex=False)

# #verifying
df.loc[df['Incident Category']=='Motor Vehicle Theft?'] # if it displays empty dataframe, then it's succeeded
# df.loc[df['Incident Category']=='Motor Vehicle Theft']
# Out:
# Empty DataFrame
# Columns: [Incident Datetime, Incident Date, Incident Time, Incident Year, Incident Day of Week, Report Datetime, Incident ID, Incident Number, Report Type Code, Report Type Description, Filed Online, Incident Code, Incident Category, Incident Subcategory, Incident Description, Incident Cost Estimate, Resolution, Police District]
# Index: []

# %% [markdown]
# Since there're only 12 missing values, removing rows of these missing data won't make too much of a different.

# %%
# Drop rows with any missing values
df_cleaned = df.dropna()

# Verify the result
print(f"Original number of rows: {len(df)}")
print(f"Number of rows after dropping missing values: {len(df_cleaned)}")
print(f"Number of missing values after dropping: {df_cleaned.isnull().sum().sum()}")
# Out:
# Original number of rows: 10000
# Number of rows after dropping missing values: 9988
# Number of missing values after dropping: 0

# %% [markdown]
# ## Export as Excel

# %%
# Define the relative path
relative_path = r"..\data\police_incident_reports_cleaned.xlsx"

# Export the cleaned DataFrame to Excel
df_cleaned.to_excel(relative_path, index=False)

# %%
import os

# Define the relative path
relative_path = os.path.join("..", "data", "police_incident_reports_cleaned.xlsx")

# Export the cleaned DataFrame to Excel
df_cleaned.to_excel(relative_path, index=False)
