# %% [markdown]
# # Setup Documents

# %% [markdown]
# ## Installing

# %% [markdown]
# 1. Pandas

# %% [markdown]
# ```ruby
# conda install anacond::pandas
# ```

# %% [markdown]
# 2. Scikit-Learn

# %% [markdown]
# ```ruby
# conda install anaconda::scikit-learn
# ```

# %% [markdown]
# 3. Numpy

# %% [markdown]
# ```ruby
# conda install anaconda::numpy
# ```

# %% [markdown]
# 4. Seaborn

# %% [markdown]
# ```ruby
# conda install anaconda::seaborn
# ```
